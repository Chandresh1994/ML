# %%
# importing liberaries
    
import numpy as np                   # is used for changing the dimension of features and more
import pandas as pd                  # is used for importing the csv
import seaborn as sns                # is used for visualizing the data
import matplotlib.pyplot as plt      # is used for plotting the data

# plotting inside ipynb
# %matplotlib inline

# %%
# visualizing the current data using seaborn

sns.countplot(y='YearsExperience', data = data_s)
# Out:
# C:\Users\mrcha\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# spliting the data

from sklearn.model_selection import train_test_split

# splitting the data into traning and test data 
# 1/3 data is used for test_data (33% )
# 2/3 data is used for train_data (77%)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
# importing linear regression 

from sklearn.linear_model import LinearRegression

lr = LinearRegression()      # create the instance of linear regression model
lr.fit(X_train, y_train)     # fit method is start the traning process
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# prediting the Test data

y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
# plotting the data for Train set

plt.scatter(X_train, y_train, color ='blue')
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.title("Salary - Experience (Train set)")
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
# plotting the data for Test set

plt.scatter(X_test, y_test, color ='blue')
plt.plot(X_train, lr.predict(X_train), color = 'red')
plt.title("Salary - Experience (Test set)")
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
# importing the dataset using pandas

# pd is a alias name of pandas 
# read_csv is a function to open a csv

data_s = pd.read_csv(r'Downloads\salary_Data.csv')

X = data_s.iloc[:, :-1].values # iloc[:, :-1] select all column without last since we have only two columns so it selects first column
y = data_s.iloc[:,1].values    # iloc[:, 1]second column of data frame
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)
